# %% [markdown]
# # Text Extraction and Analysis Pipeline
#
# # Text Extraction and Analysis
#
# This notebook implements the end-to-end pipeline  data extraction and data analysis:
#
# 1. **Data Extraction**: Read URLs from `Input.xlsx` and scrape article titles & texts.
# 2. **Text Analysis**: Compute 13 metrics (sentiment, readability, pronouns, etc.) per article.
# 3. **Output Generation**: Save results to `final_output.xlsx` following the specified structure.
#
# ---
# ```

# %%
# ## 1. Setup & Imports
import os
import re
import requests
import pandas as pd
from bs4 import BeautifulSoup
import nltk
import re
from nltk.tokenize import word_tokenize, sent_tokenize

def safe_word_tokenize(text):
    try:
        return word_tokenize(text)
    except LookupError:
        return re.findall(r'\b\w+\b', text)

def safe_sent_tokenize(text):
    try:
        return sent_tokenize(text)
    except LookupError:
        return re.split(r'[.!?]+', text)


# Download NLTK resources
nltk.download('punkt')

# Create necessary folders
os.makedirs('articles', exist_ok=True)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pdang\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
input_df = pd.read_excel('Input.xlsx')  # Expecting columns: URL_ID, URL
input_df.head()
# Out:
#             URL_ID                                                URL
# 0  Netclan20241017  https://insights.blackcoffer.com/ai-and-ml-bas...
# 1  Netclan20241018  https://insights.blackcoffer.com/enhancing-fro...
# 2  Netclan20241019  https://insights.blackcoffer.com/roas-dashboar...
# 3  Netclan20241020  https://insights.blackcoffer.com/efficient-pro...
# 4  Netclan20241021  https://insights.blackcoffer.com/development-o...

# %%
# ## 3. Data Extraction Function

def extract_article(url):
    try:
        resp = requests.get(url, timeout=10)
        soup = BeautifulSoup(resp.content, 'html.parser')
        
        # Extracting title and article
        title_tag = soup.find('h1')
        title = title_tag.get_text(strip=True) if title_tag else ''
        paragraphs = soup.find_all('p')
        body = ' '.join(p.get_text(strip=True) for p in paragraphs)
        
        full_text = f"{title}\n\n{body}"
        
        # Debug preview
        print(f"\n[URL] {url}\n[EXTRACT] {full_text[:300]}...\n")
        
        return full_text
    except Exception as e:
        print(f"Error scraping {url}: {e}")
        return ''


# Save each article as a text file
for _, row in input_df.iterrows():
    text = extract_article(row['URL'])
    with open(f"articles/{row['URL_ID']}.txt", 'w', encoding='utf-8') as f:
        f.write(text)
# Out:
# [URL] https://insights.blackcoffer.com/ai-and-ml-based-youtube-analytics-and-content-creation-tool-for-optimizing-subscriber-engagement-and-content-strategy/
# [EXTRACT] AI and ML-Based YouTube Analytics and Content Creation Tool for Optimizing Subscriber Engagement and Content Strategy
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow...
#
#
# [URL] https://insights.blackcoffer.com/enhancing-front-end-features-and-functionality-for-improved-user-experience-and-dashboard-accuracy-in-partner-hospital-application/
# [EXTRACT] Enhancing Front-End Features and Functionality for Improved User Experience and Dashboard Accuracy in Partner Hospital Application
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipelin...
#
#
# [URL] https://insights.blackcoffer.com/roas-dashboard-for-campaign-wise-google-ads-budget-tracking-using-google-ads-ap/
# [EXTRACT] ROAS Dashboard for Campaign-Wise Google Ads Budget Tracking Using Google Ads AP
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition A...
#
#
# [URL] https://insights.blackcoffer.com/efficient-processing-and-analysis-of-financial-data-from-pdf-files-addressing-formatting-inconsistencies-and-ensuring-data-integrity-for-a-toyota-dealership-management-firm/
# [EXTRACT] Efficient Processing and Analysis of Financial Data from PDF Files: Addressing Formatting Inconsistencies and Ensuring Data Integrity for a Toyota Dealership Management Firm
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating ...
#
#
# [URL] https://insights.blackcoffer.com/development-of-ea-robot-for-automated-trading/
# [EXTRACT] Development of EA Robot for Automated Trading
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text...
#
#
# [URL] https://insights.blackcoffer.com/ai-and-ml-based-youtube-analytics-and-content-creation-tool-for-optimizing-subscriber-engagement-and-content-strategy/
# [EXTRACT] AI and ML-Based YouTube Analytics and Content Creation Tool for Optimizing Subscriber Engagement and Content Strategy
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow...
#
#
# [URL] https://insights.blackcoffer.com/enhancing-front-end-features-and-functionality-for-improved-user-experience-and-dashboard-accuracy-in-partner-hospital-application/
# [EXTRACT] Enhancing Front-End Features and Functionality for Improved User Experience and Dashboard Accuracy in Partner Hospital Application
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipelin...
#
#
# [URL] https://insights.blackcoffer.com/roas-dashboard-for-campaign-wise-google-ads-budget-tracking-using-google-ads-ap/
# [EXTRACT] ROAS Dashboard for Campaign-Wise Google Ads Budget Tracking Using Google Ads AP
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition A...
#
#
# [URL] https://insights.blackcoffer.com/efficient-processing-and-analysis-of-financial-data-from-pdf-files-addressing-formatting-inconsistencies-and-ensuring-data-integrity-for-a-toyota-dealership-management-firm/
# [EXTRACT] Efficient Processing and Analysis of Financial Data from PDF Files: Addressing Formatting Inconsistencies and Ensuring Data Integrity for a Toyota Dealership Management Firm
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating ...
#
#
# [URL] https://insights.blackcoffer.com/transforming-and-managing-a-large-scale-sql-pedigree-database-to-neo4j-graph-db/
# [EXTRACT] Transforming and Managing a Large-Scale SQL Pedigree Database to Neo4j Graph DB
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition A...
#
#
# [URL] https://insights.blackcoffer.com/enhancing-model-accuracy-from-58-to-over-90-strategies-for-improving-predictive-performance/
# [EXTRACT] Enhancing Model Accuracy from 58% to Over 90%: Strategies for Improving Predictive Performance
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facia...
#
#
# [URL] https://insights.blackcoffer.com/securing-sensitive-financial-data-with-privacy-preserving-machine-learning-for-predictive-analytics/
# [EXTRACT] Securing Sensitive Financial Data with Privacy-Preserving Machine Learning for Predictive Analytics
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes ...
#
#
# [URL] https://insights.blackcoffer.com/enhancing-data-collection-for-research-institutions-addressing-survey-fatigue-and-incorporating-verbal-communication-for-richer-insights/
# [EXTRACT] Enhancing Data Collection for Research Institutions: Addressing Survey Fatigue and Incorporating Verbal Communication for Richer Insights
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow ...
#
#
# [URL] https://insights.blackcoffer.com/analyzing-the-impact-of-positive-emotions-and-pandemic-severity-on-mental-health-and-resilience-among-entrepreneurs-insights-and-predictive-modeling/
# [EXTRACT] Analyzing the Impact of Positive Emotions and Pandemic Severity on Mental Health and Resilience Among Entrepreneurs: Insights and Predictive Modeling
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code in...
#
#
# [URL] https://insights.blackcoffer.com/dynamic-brand-centric-dashboard-for-automotive-dealerships-pdf-to-financial-insights-with-flask-react-architecture-and-aws-cloud-hosting/
# [EXTRACT] Dynamic, Brand-Centric Dashboard for Automotive Dealerships: PDF to Financial Insights with Flask-React Architecture and AWS Cloud Hosting
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow...
#
#
# [URL] https://insights.blackcoffer.com/cloud-based-data-modeling-and-analysis-platform-with-drag-and-drop-interface-and-openai-api-integration-for-simulation-insights/
# [EXTRACT] Cloud-Based Data Modeling and Analysis Platform with Drag-and-Drop Interface and OpenAI API Integration for Simulation Insights
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline –...
#
#
# [URL] https://insights.blackcoffer.com/voter-profile-analysis-and-search-application-for-targeted-campaign-engagement-using-government-voter-data/
# [EXTRACT] Voter Profile Analysis and Search Application for Targeted Campaign Engagement Using Government Voter Data
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kube...
#
#
# [URL] https://insights.blackcoffer.com/bert-based-classification-of-individuals-and-organizations-into-two-categories-using-natural-language-processing/
# [EXTRACT] BERT-Based Classification of Individuals and Organizations into Two Categories Using Natural Language Processing
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOp...
#
#
# [URL] https://insights.blackcoffer.com/comprehensive-analysis-of-solana-and-ethereum-contributors-using-github-api-with-comparative-study-of-1000-random-github-profiles/
# [EXTRACT] Comprehensive Analysis of Solana and Ethereum Contributors Using GitHub API with Comparative Study of 1000 Random GitHub Profiles
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline...
#
#
# [URL] https://insights.blackcoffer.com/powerbi-rest-api-fetching-dataflow-and-refresh-schedules-with-semantic-models/
# [EXTRACT] PowerBI REST API – Fetching Dataflow and Refresh Schedules with semantic models
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition A...
#
#
# [URL] https://insights.blackcoffer.com/automated-job-data-import-and-management-solution-for-enhanced-efficiency/
# [EXTRACT] Automated Job Data Import and Management Solution for Enhanced Efficiency
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attenda...
#
#
# [URL] https://insights.blackcoffer.com/data-analytics-and-optimization-solution-for-enhancing-renewable-energy-efficiency/
# [EXTRACT] Data Analytics and Optimization Solution for Enhancing Renewable Energy Efficiency
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognitio...
#
#
# [URL] https://insights.blackcoffer.com/time-series-analysis-and-trend-forecasting-solution-for-predicting-news-trends/
# [EXTRACT] Time Series Analysis and Trend Forecasting Solution for Predicting News Trends
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition At...
#
#
# [URL] https://insights.blackcoffer.com/advanced-data-visualization-solutions-for-monitoring-key-business-metrics-with-integrated-interactive-dashboards/
# [EXTRACT] Advanced Data Visualization Solutions for Monitoring Key Business Metrics with Integrated, Interactive Dashboards
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLO...
#
#
# [URL] https://insights.blackcoffer.com/advanced-patient-data-analysis-solution-for-trend-identification-and-improved-healthcare-outcome/
# [EXTRACT] Advanced Patient Data Analysis Solution for Trend Identification and Improved Healthcare Outcome
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Fac...
#
#
# [URL] https://insights.blackcoffer.com/anomaly-detection-and-analysis-for-enhanced-data-integrity-and-user-experience-on-bright-datas-website/
# [EXTRACT] Anomaly Detection and Analysis for Enhanced Data Integrity and User Experience on Bright Data’s Website
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kuberne...
#
#
# [URL] https://insights.blackcoffer.com/building-custom-tflite-models-and-benchmarking-on-voxl2-chips/
# [EXTRACT] Building Custom TFLite Models and Benchmarking on VOXL2 Chips
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System A...
#
#
# [URL] https://insights.blackcoffer.com/sports-prediction-model-for-multiple-sports-leagues/
# [EXTRACT] Sports Prediction Model for Multiple Sports Leagues
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio an...
#
#
# [URL] https://insights.blackcoffer.com/efficient-coach-allocation-system-for-sports-coaching-organization/
# [EXTRACT] Efficient Coach Allocation System for Sports Coaching Organization
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance Sys...
#
#
# [URL] https://insights.blackcoffer.com/data-studio-dashboard-with-a-data-pipeline-tool-synced-with-podio-using-custom-webhooks-and-google-cloud-function-2/
# [EXTRACT] Data Studio Dashboard with a data pipeline tool synced with Podio using custom Webhooks and Google Cloud Function
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLO...
#
#
# [URL] https://insights.blackcoffer.com/ai-driven-backend-for-audio-to-text-conversion-and-analytical-assessment-in-pharmaceutical-practice/
# [EXTRACT] AI-Driven Backend for Audio-to-Text Conversion and Analytical Assessment in Pharmaceutical Practice
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes ...
#
#
# [URL] https://insights.blackcoffer.com/cloud-based-web-application-for-financial-data-processing-and-visualization-of-sp-500-metrics/
# [EXTRACT] Cloud-Based Web Application for Financial Data Processing and Visualization of S&P 500 Metrics
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facia...
#
#
# [URL] https://insights.blackcoffer.com/department-wise-kpi-tracking-dashboard-with-technician-performance-analysis-for-atoz-dependable-service/
# [EXTRACT] Department-Wise KPI Tracking Dashboard with Technician Performance Analysis for AtoZ Dependable Service
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kuberne...
#
#
# [URL] https://insights.blackcoffer.com/steps-to-convert-a-node-js-api-to-python-for-aws-lambda-deployment/
# [EXTRACT] Steps to Convert a Node.js API to Python for AWS Lambda Deployment
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance Sys...
#
#
# [URL] https://insights.blackcoffer.com/building-an-analytics-dashboard-with-a-pdf-parsing-pipeline-for-data-extraction/
# [EXTRACT] Building an Analytics Dashboard with a PDF Parsing Pipeline for Data Extraction
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition A...
#
#
# [URL] https://insights.blackcoffer.com/building-a-real-time-log-file-visualization-dashboard-in-kibana/
# [EXTRACT] Building a Real-Time Log File Visualization Dashboard in Kibana
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System...
#
#
# [URL] https://insights.blackcoffer.com/analyzing-the-impact-of-female-ceo-appointments-on-company-stock-prices/
# [EXTRACT] Analyzing the Impact of Female CEO Appointments on Company Stock Prices
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendanc...
#
#
# [URL] https://insights.blackcoffer.com/ai-chatbot-using-llm-langchain-llama/
# [EXTRACT] AI Chatbot using LLM, Langchain, LLama
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text conver...
#
#
# [URL] https://insights.blackcoffer.com/healthcare-ai-chatbot-using-llama-llm-langchain/
# [EXTRACT] Healthcare AI ChatBot using LLAMA, LLM, Langchain
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and ...
#
#
# [URL] https://insights.blackcoffer.com/ai-bot-audio-to-audio/
# [EXTRACT] AI Bot Audio to audio
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text conversational bot usin...
#
#
# [URL] https://insights.blackcoffer.com/recommendation-engine-for-insurance-sector-to-expand-business-in-the-rural-area/
# [EXTRACT] Recommendation Engine for Insurance Sector to Expand Business in the Rural Area
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition A...
#
#
# [URL] https://insights.blackcoffer.com/data-from-crm-via-zapier-to-google-sheets-dynamic-to-powerbi/
# [EXTRACT] Data from CRM via Zapier to Google Sheets (Dynamic) to PowerBI
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System ...
#
#
# [URL] https://insights.blackcoffer.com/data-warehouse-to-google-data-studio-looker-dashboard/
# [EXTRACT] Data Warehouse to Google Data Studio (Looker) Dashboard
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audi...
#
#
# [URL] https://insights.blackcoffer.com/crm-monday-com-via-zapier-to-power-bi-dashboard/
# [EXTRACT] CRM, Monday.com via Zapier to Power BI Dashboard
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and t...
#
#
# [URL] https://insights.blackcoffer.com/monday-com-to-kpi-dashboard-to-manage-view-and-generate-insights-from-the-crm-data/
# [EXTRACT] Monday.com to KPI Dashboard to manage, view, and generate insights from the CRM data
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognit...
#
#
# [URL] https://insights.blackcoffer.com/data-management-for-a-political-saas-application/
# [EXTRACT] Data Management for a Political SaaS Application
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and t...
#
#
# [URL] https://insights.blackcoffer.com/google-lsa-ads-google-local-service-ads-etl-tools-and-dashboards/
# [EXTRACT] Google LSA Ads (Google Local Service Ads) – ETL tools and Dashboards
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance S...
#
#
# [URL] https://insights.blackcoffer.com/ad-networks-marketing-campaign-data-dashboard-in-looker-google-data-studio/
# [EXTRACT] Ad Networks Marketing Campaign Data Dashboard in Looker (Google Data Studio)
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Atte...
#
#
# [URL] https://insights.blackcoffer.com/analytical-solution-for-a-tech-firm/
# [EXTRACT] Analytical solution for a tech firm
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text conversat...
#
#
# [URL] https://insights.blackcoffer.com/ai-solution-for-a-technology-information-and-internet-firm/
# [EXTRACT] AI solution for a Technology, Information and Internet firm
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI ...
#
#
# [URL] https://insights.blackcoffer.com/ai-and-nlp-based-solutions-to-automate-data-discovery-for-venture-capital-and-private-equity-principals/
# [EXTRACT] AI and NLP-based Solutions to Automate Data Discovery for Venture Capital and Private Equity Principals
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kuberne...
#
#
# [URL] https://insights.blackcoffer.com/an-etl-solution-for-an-internet-publishing-firm/
# [EXTRACT] An ETL solution for an Internet Publishing firm
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and te...
#
#
# [URL] https://insights.blackcoffer.com/ai-based-algorithmic-trading-bot-for-forex/
# [EXTRACT] AI-Based Algorithmic Trading Bot for Forex
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text co...
#
#
# [URL] https://insights.blackcoffer.com/equity-waterfalls-model-based-saas-application-for-real-estate-sector/
# [EXTRACT] Equity Waterfalls Model-Based SaaS Application for Real Estate Sector
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance ...
#
#
# [URL] https://insights.blackcoffer.com/ai-solutions-for-foreign-exchange-an-automated-algo-trading-tool/
# [EXTRACT] AI Solutions for Foreign Exchange – An Automated Algo Trading Tool
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance Sys...
#
#
# [URL] https://insights.blackcoffer.com/ai-agent-development-and-deployment-in-jina-ai/
# [EXTRACT] AI agent development and Deployment in Jina AI
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and tex...
#
#
# [URL] https://insights.blackcoffer.com/golden-record-a-knowledge-graph-database-approach-to-unfold-discovery-using-neo4j/
# [EXTRACT] Golden Record – A knowledge graph database approach to unfold discovery using Neo4j
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recogniti...
#
#
# [URL] https://insights.blackcoffer.com/advanced-ai-for-trading-automation/
# [EXTRACT] Advanced AI for Trading Automation
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text conversati...
#
#
# [URL] https://insights.blackcoffer.com/create-a-knowledge-graph-to-provide-real-time-analytics-recommendations-and-a-single-source-of-truth/
# [EXTRACT] Create a Knowledge Graph to Provide Real-time Analytics, Recommendations, and a Single Source of Truth
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernet...
#
#
# [URL] https://insights.blackcoffer.com/advanced-ai-for-thermal-person-detection/
# [EXTRACT] Advanced AI for Thermal Person Detection
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text conv...
#
#
# [URL] https://insights.blackcoffer.com/advanced-ai-for-road-cam-threat-detection/
# [EXTRACT] Advanced AI for Road Cam Threat Detection
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text con...
#
#
# [URL] https://insights.blackcoffer.com/advanced-ai-for-pedestrian-crossing-safety/
# [EXTRACT] Advanced AI for Pedestrian Crossing Safety
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text co...
#
#
# [URL] https://insights.blackcoffer.com/handgun-detection-using-yolo/
# [EXTRACT] Advanced AI for Handgun Detection
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text conversatio...
#
#
# [URL] https://insights.blackcoffer.com/using-graph-technology-to-create-single-customer-view/
# [EXTRACT] Using Graph Technology to Create Single Customer View.
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio...
#
#
# [URL] https://insights.blackcoffer.com/car-detection-in-satellite-images/
# [EXTRACT] Car Detection in Satellite Images
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text conversatio...
#
#
# [URL] https://insights.blackcoffer.com/building-a-physics-informed-neural-network-for-circuit-evaluation/
# [EXTRACT] Building a Physics-Informed Neural Network for Circuit Evaluation
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance Syst...
#
#
# [URL] https://insights.blackcoffer.com/connecting-mongodb-database-to-power-bi-dashboard-dashboard-automation/
# [EXTRACT] Connecting MongoDB Database to Power BI Dashboard: Dashboard Automation
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendanc...
#
#
# [URL] https://insights.blackcoffer.com/data-transformation/
# [EXTRACT] Data Transformation
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text conversational bot using ...
#
#
# [URL] https://insights.blackcoffer.com/e-commerce-store-analysis-purchase-behavior-ad-spend-conversion-traffic-etc/
# [EXTRACT] E-commerce Store Analysis – Purchase Behavior, Ad Spend, Conversion, Traffic, etc…
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognitio...
#
#
# [URL] https://insights.blackcoffer.com/kpi-dashboard-for-accountants/
# [EXTRACT] KPI Dashboard for Accountants
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text conversational ...
#
#
# [URL] https://insights.blackcoffer.com/return-on-advertising-spend-dashboard-marketing-automation-and-analytics-using-etl-and-dashboard/
# [EXTRACT] Return on Advertising Spend Dashboard: Marketing Automation and Analytics using ETL and Dashboard
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Fa...
#
#
# [URL] https://insights.blackcoffer.com/ranking-customer-behaviours-for-business-strategy/
# [EXTRACT] Ranking customer behaviours for business strategy
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and ...
#
#
# [URL] https://insights.blackcoffer.com/algorithmic-trading-for-multiple-commodities-markets-like-forex-metals-energy-etc/
# [EXTRACT] Algorithmic trading for multiple commodities markets, like Forex, Metals, Energy, etc.
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recogn...
#
#
# [URL] https://insights.blackcoffer.com/trading-bot-for-forex/
# [EXTRACT] Trading Bot for FOREX
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text conversational bot usin...
#
#
# [URL] https://insights.blackcoffer.com/python-model-for-the-analysis-of-sector-specific-stock-etfs-for-investment-purposes%ef%bf%bc/
# [EXTRACT] Python model for the analysis of sector-specific stock ETFs for investment purposes
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recogniti...
#
#
# [URL] https://insights.blackcoffer.com/medical-classification/
# [EXTRACT] Medical Classification
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text conversational bot usi...
#
#
# [URL] https://insights.blackcoffer.com/design-develop-bert-question-answering-model-explanations-with-visualization/
# [EXTRACT] Design & Develop BERT Question Answering model explanations with visualization
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition At...
#
#
# [URL] https://insights.blackcoffer.com/design-and-develop-solution-to-anomaly-detection-classification-problems/
# [EXTRACT] Design and develop solution to anomaly detection classification problems
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendan...
#
#
# [URL] https://insights.blackcoffer.com/an-etl-solution-for-currency-data-to-google-big-query/
# [EXTRACT] An ETL Solution for Currency Data to Google Big Query
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio ...
#
#
# [URL] https://insights.blackcoffer.com/etl-and-mlops-infrastructure-for-blockchain-analytics/
# [EXTRACT] ETL and MLOps Infrastructure for Blockchain Analytics
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio ...
#
#
# [URL] https://insights.blackcoffer.com/an-agent-based-model-of-a-virtual-power-plant-vpp/
# [EXTRACT] An agent-based model of a Virtual Power Plant (VPP)
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio an...
#
#
# [URL] https://insights.blackcoffer.com/transform-api-into-sdk-library-and-widget/
# [EXTRACT] Transform API into SDK library and widget
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text con...
#
#
# [URL] https://insights.blackcoffer.com/integration-of-a-product-to-a-cloud-based-crm-platform/
# [EXTRACT] Integration of a product to a cloud-based CRM platform
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio...
#
#
# [URL] https://insights.blackcoffer.com/a-web-based-dashboard-for-the-filtered-data-retrieval-of-land-records/
# [EXTRACT] A web-based dashboard for the filtered data retrieval of land records
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance ...
#
#
# [URL] https://insights.blackcoffer.com/integration-of-video-conferencing-data-to-the-existing-web-app/
# [EXTRACT] Integration of video-conferencing data to the existing web app
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System ...
#
#
# [URL] https://insights.blackcoffer.com/design-develop-an-app-in-retool-which-shows-the-progress-of-the-added-video/
# [EXTRACT] Design & develop an app in retool which shows the progress of the added video
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Att...
#
#
# [URL] https://insights.blackcoffer.com/auvik-connectwise-integration-in-grafana/
# [EXTRACT] Auvik, Connectwise integration in Grafana
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text con...
#
#
# [URL] https://insights.blackcoffer.com/data-integration-and-big-data-performance-using-elk-stack/
# [EXTRACT] Data integration and big data performance using Elasticsearch
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System A...
#
#
# [URL] https://insights.blackcoffer.com/web-data-connector/
# [EXTRACT] Web Data Connector
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text conversational bot using l...
#
#
# [URL] https://insights.blackcoffer.com/an-app-for-updating-the-email-id-of-the-user-and-stripe-refund-tool-using-retool/
# [EXTRACT] An app for updating the email id of the user and stripe refund tool using retool
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition ...
#
#
# [URL] https://insights.blackcoffer.com/an-ai-ml-based-web-application-that-detects-the-correctness-of-text-in-a-given-video/
# [EXTRACT] An AI ML-based web application that detects the correctness of text in a given video
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognit...
#
#
# [URL] https://insights.blackcoffer.com/website-tracking-and-insights-using-google-analytics-google-tag-manager/
# [EXTRACT] Website Tracking and Insights using Google Analytics, & Google Tag Manager
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attend...
#
#
# [URL] https://insights.blackcoffer.com/dashboard-to-track-the-analytics-of-the-website-using-google-analytics-and-google-tag-manager/
# [EXTRACT] Dashboard to track the analytics of the website using Google Analytics and Google Tag Manager
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial...
#
#
# [URL] https://insights.blackcoffer.com/power-bi-dashboard-on-operations-transactions-and-marketing-embedding-the-dashboard-to-web-app/
# [EXTRACT] Power BI Dashboard on Operations, Transactions, and Marketing Data, embedding the Dashboard to Web App
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernet...
#
#
# [URL] https://insights.blackcoffer.com/nft-data-automation-looksrare-and-etl-tool/
# [EXTRACT] NFT Data Automation (looksrare), and ETL tool
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text...
#
#
# [URL] https://insights.blackcoffer.com/optimize-the-data-scraper-program-to-easily-accommodate-large-files-and-solve-oom-errors/
# [EXTRACT] Optimize the data scraper program to easily accommodate large files and solve OOM errors
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Reco...
#
#
# [URL] https://insights.blackcoffer.com/making-a-robust-way-to-sync-data-from-airtables-to-mongodb-using-python-etl-solution/
# [EXTRACT] Making a robust way to sync data from airtables to mongoDB using python – ETL Solution
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recogn...
#
#
# [URL] https://insights.blackcoffer.com/incident-duration-prediction-infrastructure-and-real-estate/
# [EXTRACT] Incident Duration Prediction – Infrastructure and Real Estate
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System A...
#
#
# [URL] https://insights.blackcoffer.com/statistical-data-analysis-of-reinforced-concrete/
# [EXTRACT] Statistical Data Analysis of Reinforced Concrete
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and t...
#
#
# [URL] https://insights.blackcoffer.com/database-normalization-segmentation-with-google-data-studio-dashboard-insights/
# [EXTRACT] Database Normalization & Segmentation with Google Data Studio Dashboard Insights
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition ...
#
#
# [URL] https://insights.blackcoffer.com/power-bi-dashboard-to-drive-insights-from-complex-data-to-generate-business-insights/
# [EXTRACT] Power BI dashboard to drive insights from complex data to generate business insights
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognit...
#
#
# [URL] https://insights.blackcoffer.com/real-time-dashboard-to-monitor-infrastructure-activity-and-machines/
# [EXTRACT] Real-time dashboard to monitor infrastructure activity and Machines
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance Sy...
#
#
# [URL] https://insights.blackcoffer.com/electric-vehicles-ev-load-management-system-to-forecast-energy-demand/
# [EXTRACT] Electric Vehicles (EV) Load Management System to Forecast Energy Demand
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendanc...
#
#
# [URL] https://insights.blackcoffer.com/power-bi-data-driven-map-dashboard/
# [EXTRACT] Power BI Data-Driven Map Dashboard
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text conversati...
#
#
# [URL] https://insights.blackcoffer.com/google-local-service-ads-lsa-leads-dashboard/
# [EXTRACT] Google Local Service Ads (LSA) Leads Dashboard
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and tex...
#
#
# [URL] https://insights.blackcoffer.com/aws-lex-voice-and-chatbot/
# [EXTRACT] AWS Lex Voice and Chatbot
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text conversational bot ...
#
#
# [URL] https://insights.blackcoffer.com/metabridges-api-decentraland-integration/
# [EXTRACT] MetaBridges API Decentraland Integration – AR, VR
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and ...
#
#
# [URL] https://insights.blackcoffer.com/microsoft-azure-chatbot-with-luis-language-understanding/
# [EXTRACT] Microsoft Azure chatbot with LUIS (Language Understanding)
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI a...
#
#
# [URL] https://insights.blackcoffer.com/impact-of-news-media-and-press-on-innovation-startups-and-investments/
# [EXTRACT] Impact of news, media, and press on innovation, startups, and investments
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attenda...
#
#
# [URL] https://insights.blackcoffer.com/aws-quicksight-reporting-dashboard/
# [EXTRACT] AWS QuickSight Reporting Dashboard
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text conversati...
#
#
# [URL] https://insights.blackcoffer.com/google-data-studio-dashboard-for-marketing-ads-and-traction-data/
# [EXTRACT] Google Data Studio Dashboard for Marketing, ads and Traction data
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance Syst...
#
#
# [URL] https://insights.blackcoffer.com/gangala-in-e-commerce-big-data-etl-elt-solution-and-data-warehouse/
# [EXTRACT] Gangala.in: E-commerce Big Data ETL / ELT Solution and Data Warehouse
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance ...
#
#
# [URL] https://insights.blackcoffer.com/big-data-solution-to-an-online-multivendor-marketplace-ecommerce-business/
# [EXTRACT] Big Data solution to an online multivendor marketplace eCommerce business
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attenda...
#
#
# [URL] https://insights.blackcoffer.com/creating-a-custom-report-and-dashboard-using-the-data-got-from-atera-api/
# [EXTRACT] Creating a custom report and dashboard using the data got from Atera API
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendan...
#
#
# [URL] https://insights.blackcoffer.com/azure-data-lake-and-power-bi-dashboard/
# [EXTRACT] Azure Data Lake and Power BI Dashboard
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text conver...
#
#
# [URL] https://insights.blackcoffer.com/google-data-studio-pipeline-with-gcp-mysql/
# [EXTRACT] Google Data Studio Pipeline with GCP/MySQL
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text co...
#
#
# [URL] https://insights.blackcoffer.com/quickbooks-dashboard-to-find-patterns-in-finance-sales-and-forecasts/
# [EXTRACT] QuickBooks dashboard to find patterns in finance, sales, and forecasts
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance...
#
#
# [URL] https://insights.blackcoffer.com/marketing-sales-and-financial-data-business-dashboard-wink-report/
# [EXTRACT] Marketing, sales, and financial data business dashboard (Wink Report)
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance ...
#
#
# [URL] https://insights.blackcoffer.com/react-native-apps-in-the-development-portfolio/
# [EXTRACT] React Native Apps in the Development Portfolio
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and tex...
#
#
# [URL] https://insights.blackcoffer.com/a-leading-firm-website-seo-optimization/
# [EXTRACT] A Leading Law Firm in the USA, Website SEO & Optimization
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI au...
#
#
# [URL] https://insights.blackcoffer.com/a-leading-hospitality-firm-in-the-usa-website-seo-optimization/
# [EXTRACT] A Leading Hospitality Firm in the USA, Website SEO & Optimization
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance Syst...
#
#
# [URL] https://insights.blackcoffer.com/a-leading-firm-in-the-usa-website-seo-optimization/
# [EXTRACT] A Leading Firm in the USA, Website SEO & Optimization
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio ...
#
#
# [URL] https://insights.blackcoffer.com/a-leading-musical-instrumental-website-seo-optimization/
# [EXTRACT] A Leading Musical Instrumental, Website SEO & Optimization
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI a...
#
#
# [URL] https://insights.blackcoffer.com/a-leading-firm-in-the-usa-seo-and-website-optimization/
# [EXTRACT] A Leading Firm in the USA, SEO and Website Optimization
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audi...
#
#
# [URL] https://insights.blackcoffer.com/immigration-datawarehouse-ai-based-recommendations/
# [EXTRACT] Immigration Datawarehouse & AI-based recommendations
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio a...
#
#
# [URL] https://insights.blackcoffer.com/lipsync-automation-for-celebrities-and-influencers/
# [EXTRACT] Lipsync Automation for Celebrities and Influencers
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and...
#
#
# [URL] https://insights.blackcoffer.com/key-audit-matters-predictive-modeling/
# [EXTRACT] Key Audit Matters Predictive Modeling
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text convers...
#
#
# [URL] https://insights.blackcoffer.com/splitting-of-songs-into-its-vocals-and-instrumental/
# [EXTRACT] Splitting of Songs into its Vocals and Instrumental
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio an...
#
#
# [URL] https://insights.blackcoffer.com/ai-and-ml-technologies-to-evaluate-learning-assessments/
# [EXTRACT] AI and ML technologies to Evaluate Learning Assessments
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audi...
#
#
# [URL] https://insights.blackcoffer.com/datawarehouse-and-recommendations-engine-for-airbnb/
# [EXTRACT] Datawarehouse, and Recommendations Engine for AirBNB
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio a...
#
#
# [URL] https://insights.blackcoffer.com/real-estate-data-warehouse/
# [EXTRACT] Real Estate Data Warehouse
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text conversational bot...
#
#
# [URL] https://insights.blackcoffer.com/traction-dashboards-of-marketing-campaigns-and-posts/
# [EXTRACT] Traction Dashboards of Marketing Campaigns and Posts
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio a...
#
#
# [URL] https://insights.blackcoffer.com/google-local-service-ads-lsa-data-warehouse/
# [EXTRACT] Google Local Service Ads (LSA) Data Warehouse
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text...
#
#
# [URL] https://insights.blackcoffer.com/google-local-service-ads-missed-calls-and-messages-automation-tool/
# [EXTRACT] Google Local Service Ads Missed Calls and Messages Automation Tool
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance Sys...
#
#
# [URL] https://insights.blackcoffer.com/marketing-ads-leads-call-status-data-tool-to-bigquery/
# [EXTRACT] Marketing Ads Leads Call Status Data Tool to BigQuery
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio ...
#
#
# [URL] https://insights.blackcoffer.com/marketing-analytics-to-automate-leads-call-status-and-reporting/
# [EXTRACT] Marketing Analytics to Automate Leads Call Status and Reporting
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System...
#
#
# [URL] https://insights.blackcoffer.com/callrail-analytics-leads-report-alert/
# [EXTRACT] CallRail, Analytics & Leads Report Alert
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text conv...
#
#
# [URL] https://insights.blackcoffer.com/marketing-automation-tool-to-notify-lead-details-to-clients-over-email-and-phone/
# [EXTRACT] Marketing Tool to Notify Leads to Clients over Email and Phone
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System ...
#
#
# [URL] https://insights.blackcoffer.com/data-etl-local-service-ads-leads-to-bigquery/
# [EXTRACT] Data ETL: Local Service Ads Leads to BigQuery
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text...
#
#
# [URL] https://insights.blackcoffer.com/marbles-stimulation-using-python/
# [EXTRACT] Marbles Stimulation using python
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text conversation...
#
#
# [URL] https://insights.blackcoffer.com/stocktwits-data-structurization/
# [EXTRACT] Stocktwits Data Structurization
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text conversationa...
#
#
# [URL] https://insights.blackcoffer.com/sentimental-analysis-on-shareholder-letter-of-companies/
# [EXTRACT] Sentimental Analysis on Shareholder Letter of Companies
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audi...
#
#
# [URL] https://insights.blackcoffer.com/population-and-community-survey-of-america/
# [EXTRACT] Population and Community Survey of America
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text co...
#
#
# [URL] https://insights.blackcoffer.com/google-lsa-api-data-automation-and-dashboarding/
# [EXTRACT] Google LSA API Data Automation and Dashboarding
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and te...
#
#
# [URL] https://insights.blackcoffer.com/healthcare-data-analysis/
# [EXTRACT] Healthcare Data Analysis
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text conversational bot u...
#
#
# [URL] https://insights.blackcoffer.com/budget-sales-kpi-dashboard-using-power-bi/
# [EXTRACT] Budget, Sales KPI Dashboard using Power BI
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audio and text co...
#
#
# [URL] https://insights.blackcoffer.com/amazon-buy-bot-an-automation-ai-tool-to-auto-checkouts/
# [EXTRACT] Amazon Buy Bot, an Automation AI tool to Auto-Checkouts
#
# Transforming Real Estate Investments with an Automated Stack shares Platform Empowering Careers: The Hirekingdom Integrating Machine Learning Code into Kubeflow Pipeline – Kuberflow MLOps Kubernetes Facial Recognition Attendance System AI audi...

# %%
def load_stopwords(folder='StopWords'):
    stopwords = set()
    for fname in os.listdir(folder):
        path = os.path.join(folder, fname)
        try:
            with open(path, 'r', encoding='utf-8') as f:
                stopwords |= set(f.read().lower().split())
        except UnicodeDecodeError:
            with open(path, 'r', encoding='ISO-8859-1') as f:
                stopwords |= set(f.read().lower().split())
    return stopwords


def load_master_dict(folder='MasterDictionary'):
    with open(os.path.join(folder, 'positive-words.txt'), encoding='utf-8', errors='ignore') as f:
        positive = set(f.read().lower().split())
    with open(os.path.join(folder, 'negative-words.txt'), encoding='utf-8', errors='ignore') as f:
        negative = set(f.read().lower().split())
    return positive, negative

stop_words = load_stopwords()
positive_words, negative_words = load_master_dict()

# %%
def count_syllables(word):
    word = word.lower()
    syllables = len(re.findall(r'[aeiouy]+', word))
    if word.endswith(('es', 'ed')) and len(word) > 2:
        syllables -= 1
    return max(syllables, 1)

# %%
def analyze_text(text):
    try:
        tokens = safe_word_tokenize(text.lower())
        words = [re.sub(r"\W+", "", w) for w in tokens if w.isalpha()]
        words = [w for w in words if w not in stop_words]
        sentences = safe_sent_tokenize(text)
        sentences = [s for s in sentences if s.strip()]

        if not words or not sentences:
            raise ValueError(f"Empty words or sentences. Raw text: {text[:200]}")

        # (rest of the logic stays the same)


        # Step 3: Sentiment
        pos_score = sum(w in positive_words for w in words)
        neg_score = sum(w in negative_words for w in words)
        polarity = (pos_score - neg_score) / ((pos_score + neg_score) + 1e-6)
        subjectivity = (pos_score + neg_score) / (len(words) + 1e-6)

        # Step 4: Readability
        avg_sent_len = len(words) / len(sentences)
        complex_words = [w for w in words if count_syllables(w) > 2]
        percent_complex = len(complex_words) / len(words)
        fog_index = 0.4 * (avg_sent_len + percent_complex)
        avg_words_per_sentence = avg_sent_len
        complex_word_count = len(complex_words)

        # Step 5: Other Metrics
        word_count = len(words)
        syllables_per_word = sum(count_syllables(w) for w in words) / word_count
        pronouns = len(re.findall(r'\b(I|we|my|ours|us)\b', text, flags=re.I))
        avg_word_length = sum(len(w) for w in words) / word_count

        return [
            pos_score, neg_score, polarity, subjectivity,
            avg_sent_len, percent_complex, fog_index, avg_words_per_sentence,
            complex_word_count, word_count, syllables_per_word, pronouns, avg_word_length
        ]
    
    except Exception as e:
        print(f"Error in analyze_text: {e}")
        return [None] * 13

# %%
# ## 6. Generate Output

import warnings
warnings.filterwarnings("ignore")

# Prepare output DataFrame
output_df = input_df.copy()
cols = [
    'POSITIVE SCORE', 'NEGATIVE SCORE', 'POLARITY SCORE', 'SUBJECTIVITY SCORE',
    'AVG SENTENCE LENGTH', 'PERCENTAGE OF COMPLEX WORDS', 'FOG INDEX', 'AVG NUMBER OF WORDS PER SENTENCE',
    'COMPLEX WORD COUNT', 'WORD COUNT', 'SYLLABLE PER WORD', 'PERSONAL PRONOUNS', 'AVG WORD LENGTH'
]
for c in cols:
    output_df[c] = None  # safer than 0.0 for missing/invalid entries

# Analyze each article
for idx, row in output_df.iterrows():
    file_path = f"articles/{row['URL_ID']}.txt"
    if os.path.isfile(file_path):
        try:
            with open(file_path, encoding='utf-8') as f:
                text = f.read()
            metrics = analyze_text(text)
            for i, c in enumerate(cols):
                output_df.at[idx, c] = metrics[i]
        except Exception as e:
            print(f"Error processing {file_path}: {e}")
    else:
        print(f"Missing: {file_path}")

# Save final results
output_df.to_excel('final_output.xlsx', index=False)
output_df.head()
# Out:
#             URL_ID                                                URL  \
# 0  Netclan20241017  https://insights.blackcoffer.com/ai-and-ml-bas...
# 1  Netclan20241018  https://insights.blackcoffer.com/enhancing-fro...
# 2  Netclan20241019  https://insights.blackcoffer.com/roas-dashboar...
# 3  Netclan20241020  https://insights.blackcoffer.com/efficient-pro...
# 4  Netclan20241021  https://insights.blackcoffer.com/development-o...
#
#   POSITIVE SCORE NEGATIVE SCORE POLARITY SCORE SUBJECTIVITY SCORE  \
# 0              8              0            1.0           0.032922
# 1             15              7       0.363636           0.043393
# 2             13              2       0.733333           0.053571
# 3             26             11       0.405405           0.074899
# 4              5              0            1.0           0.021097
#
#   AVG SENTENCE LENGTH PERCENTAGE OF COMPLEX WORDS FOG INDEX  \
# 0           14.294118                    0.514403  5.923408
# 1           10.787234                    0.398422  4.474262
# 2           14.736842                    0.414286  6.060451
# 3           13.351351                    0.544534  5.558354
# 4           13.166667                     0.49789  5.465823
#
#   AVG NUMBER OF WORDS PER SENTENCE COMPLEX WORD COUNT WORD COUNT  \
# 0                        14.294118                125        243
# 1                        10.787234                202        507
# 2                        14.736842                116        280
# 3                        13.351351                269        494
# 4                        13.166667                118        237
#
#   SYLLABLE PER WORD PERSONAL PRONOUNS AVG WORD LENGTH
# 0          2.625514                 3        7.781893
# 1          2.416174                 9        7.195266
# 2          2.492857                 3             7.4
# 3          2.718623                 6         7.98583
# 4          2.662447                 3        7.637131
